# %% [markdown]
# <a href="https://colab.research.google.com/github/asdanomar15/Final_Project/blob/main/text_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
python_packages="""pandas
numpy
seaborn
matplotlib"""
with open ("requirements.txt",'w')as f:
  f.write(python_packages)
print('Done')
# Out:
# Done
